# %% [markdown]
# # Import the Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Load the dataset

# %%
dftrain= pd.read_csv("Train.csv")
dftest= pd.read_csv("Test.csv")
print(dftrain.shape)
print(dftest.shape)
# Out:
# (8523, 12)
# (5681, 11)

# %%
#Combine them into a single dataset
dftrain['src']='train'
dftest['src']='test'
df= pd.concat([dftrain,dftest], ignore_index=True)
df
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.000000
# 4               NCD19         8.93          Low Fat         0.000000
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular         0.013496
# 14200           FDD47         7.60          Regular         0.142991
# 14201           NCO17        10.00          Low Fat         0.073529
# 14202           FDJ26        15.30          Regular         0.000000
# 14203           FDU37         9.50          Regular         0.104720
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# ...

# %%
df.describe()
# Out:
#         Item_Weight  Item_Visibility      Item_MRP  Outlet_Establishment_Year  \
# count  11765.000000     14204.000000  14204.000000               14204.000000
# mean      12.792854         0.065953    141.004977                1997.830681
# std        4.652502         0.051459     62.086938                   8.371664
# min        4.555000         0.000000     31.290000                1985.000000
# 25%        8.710000         0.027036     94.012000                1987.000000
# 50%       12.600000         0.054021    142.247000                1999.000000
# 75%       16.750000         0.094037    185.855600                2004.000000
# max       21.350000         0.328391    266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14204 entries, 0 to 14203
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            14204 non-null  object
#  1   Item_Weight                11765 non-null  float64
#  2   Item_Fat_Content           14204 non-null  object
#  3   Item_Visibility            14204 non-null  float64
#  4   Item_Type                  14204 non-null  object
#  5   Item_MRP                   14204 non-null  float64
#  6   Outlet_Identifier          14204 non-null  object
#  7   Outlet_Establishment_Year  14204 non-null  int64
#  8   Outlet_Size                10188 non-null  object
#  9   Outlet_Location_Type       14204 non-null  object
#  10  Outlet_Type                14204 non-null  object
#  11  Item_Outlet_Sales          8523 non-null   float64
#  12  src                        14204 non-null  object
# ...

# %%
df.apply(lambda x:len(x.unique()))
# Out:
# Item_Identifier               1559
# Item_Weight                    416
# Item_Fat_Content                 5
# Item_Visibility              13006
# Item_Type                       16
# Item_MRP                      8052
# Outlet_Identifier               10
# Outlet_Establishment_Year        9
# Outlet_Size                      4
# Outlet_Location_Type             3
# Outlet_Type                      4
# Item_Outlet_Sales             3494
# src                              2
# dtype: int64

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Null Values

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  2439
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  4016
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales            5681
# src                             0
# dtype: int64

# %%
#Replacing null values.
weight_mean= df.pivot_table(values='Item_Weight', index='Item_Identifier')
weight_mean
# Out:
#                  Item_Weight
# Item_Identifier
# DRA12                 11.600
# DRA24                 19.350
# DRA59                  8.270
# DRB01                  7.390
# DRB13                  6.115
# ...                      ...
# NCZ30                  6.590
# NCZ41                 19.850
# NCZ42                 10.500
# NCZ53                  9.600
# NCZ54                 14.650
#
# [1559 rows x 1 columns]

# %%
bool= df['Item_Weight'].isnull()
bool
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14199    False
# 14200    False
# 14201    False
# 14202    False
# 14203    False
# Name: Item_Weight, Length: 14204, dtype: bool

# %%
for i,item in enumerate(df['Item_Identifier']):
    if(bool[i]):
        if item in weight_mean:
            df['Item_Weight'][i]='weight_mean'.loc[item]['Item_Weight']
        else:
            df['Item_Weight'][i]= df['Item_Weight'].mean()
# Out:
# <ipython-input-10-851cdc823e85>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Item_Weight'][i]= df['Item_Weight'].mean()

# %%
outlet_mode= df.pivot_table(values='Outlet_Size', columns='Outlet_Type', aggfunc=(lambda x: x.mode()[0]))
outlet_mode
# Out:
# Outlet_Type Grocery Store Supermarket Type1 Supermarket Type2  \
# Outlet_Size         Small             Small            Medium
#
# Outlet_Type Supermarket Type3
# Outlet_Size            Medium

# %%
bool= df['Outlet_Size'].isnull()
bool
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 14199    False
# 14200    False
# 14201     True
# 14202     True
# 14203     True
# Name: Outlet_Size, Length: 14204, dtype: bool

# %%
df.loc[bool,'Outlet_Size']= df.loc[bool,'Outlet_Type'].apply(lambda x: outlet_mode[x])

# %%
df['Outlet_Size'].isnull().sum()
# Out:
# 0

# %%
#Replace 0's with mean
df.loc[:'Item_Visibility'].replace([0], df['Item_Visibility'].mean(), inplace=True)

# %%
#Aggregating item fat content
df['Item_Fat_Content']=df['Item_Fat_Content'].replace({'LF':'Low Fat', 'low fat': 'Low Fat', 'reg':'Regular'})
df['Item_Fat_Content']
# Out:
# 0        Low Fat
# 1        Regular
# 2        Low Fat
# 3        Regular
# 4        Low Fat
#           ...
# 14199    Regular
# 14200    Regular
# 14201    Low Fat
# 14202    Regular
# 14203    Regular
# Name: Item_Fat_Content, Length: 14204, dtype: object

# %% [markdown]
# ### Creating new attributes

# %%
df['New_Item_type']= df['Item_Identifier'].apply(lambda x: x[:2])
df['New_Item_type']
# Out:
# 0        FD
# 1        DR
# 2        FD
# 3        FD
# 4        NC
#          ..
# 14199    FD
# 14200    FD
# 14201    NC
# 14202    FD
# 14203    FD
# Name: New_Item_type, Length: 14204, dtype: object

# %%
df['New_Item_type'].replace({'FD':'Food', 'DR':'Drinks', 'NC':'Non-Consumable'}, inplace=True)

# %%
df.loc[df['New_Item_type']=='Non-Consumable','Item_Fat_Content']='Inedible'
df
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.065953
# 4               NCD19         8.93         Inedible         0.065953
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular         0.013496
# 14200           FDD47         7.60          Regular         0.142991
# 14201           NCO17        10.00         Inedible         0.073529
# 14202           FDJ26        15.30          Regular         0.065953
# 14203           FDU37         9.50          Regular         0.104720
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# ...

# %%
# Creating a new column with smaller values of Outlet Establishment Year
df['Year']= 2021-df['Outlet_Establishment_Year']
df
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.065953
# 4               NCD19         8.93         Inedible         0.065953
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular         0.013496
# 14200           FDD47         7.60          Regular         0.142991
# 14201           NCO17        10.00         Inedible         0.073529
# 14202           FDJ26        15.30          Regular         0.065953
# 14203           FDU37         9.50          Regular         0.104720
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# ...

# %% [markdown]
# ### Categorical Values

# %%
#Getting categorical columns in the dataset
categ=[]
for c in df.dtypes.index:
    if(df.dtypes[c]=='object'):
        categ.append(c)
categ
# Out:
# ['Item_Identifier',
#  'Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Identifier',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type',
#  'src',
#  'New_Item_type']

# %%
categ.remove('Item_Identifier')
categ.remove('Outlet_Identifier')
categ
# Out:
# ['Item_Fat_Content',
#  'Item_Type',
#  'Outlet_Size',
#  'Outlet_Location_Type',
#  'Outlet_Type',
#  'src',
#  'New_Item_type']

# %%
for c in categ:
    print(c)
    print(df[c].value_counts())
    print()
# Out:
# Item_Fat_Content
# Low Fat     6499
# Regular     5019
# Inedible    2686
# Name: Item_Fat_Content, dtype: int64
#
# Item_Type
# Fruits and Vegetables    2013
# Snack Foods              1989
# Household                1548
# Frozen Foods             1426
# Dairy                    1136
# Baking Goods             1086
# Canned                   1084
# Health and Hygiene        858
# Meat                      736
# Soft Drinks               726
# Breads                    416
# Hard Drinks               362
# Others                    280
# Starchy Foods             269
# Breakfast                 186
# Seafood                    89
# Name: Item_Type, dtype: int64
#
# Outlet_Size
# Small     7996
# Medium    4655
# High      1553
# Name: Outlet_Size, dtype: int64
#
# Outlet_Location_Type
# Tier 3    5583
# Tier 2    4641
# Tier 1    3980
# Name: Outlet_Location_Type, dtype: int64
#
# Outlet_Type
# Supermarket Type1    9294
# Grocery Store        1805
# Supermarket Type3    1559
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
df
# Out:
#       Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0               FDA15         9.30          Low Fat         0.016047
# 1               DRC01         5.92          Regular         0.019278
# 2               FDN15        17.50          Low Fat         0.016760
# 3               FDX07        19.20          Regular         0.065953
# 4               NCD19         8.93         Inedible         0.065953
# ...               ...          ...              ...              ...
# 14199           FDB58        10.50          Regular         0.013496
# 14200           FDD47         7.60          Regular         0.142991
# 14201           NCO17        10.00         Inedible         0.073529
# 14202           FDJ26        15.30          Regular         0.065953
# 14203           FDU37         9.50          Regular         0.104720
#
#                    Item_Type  Item_MRP Outlet_Identifier  \
# 0                      Dairy  249.8092            OUT049
# ...

# %%
plt.plot(df['Item_Outlet_Sales'])

# %%
sns.pairplot(df)

# %%
#plotting against numeric data
sns.distplot(df['Item_Weight'])
# Out:
# C:\Users\mehta\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Item_Weight', ylabel='Density'>

# %%
sns.distplot(df['Item_Visibility'])
# Out:
# C:\Users\mehta\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Item_Visibility', ylabel='Density'>

# %%
sns.distplot(df['Item_MRP'])
# Out:
# C:\Users\mehta\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Item_MRP', ylabel='Density'>

# %%
sns.distplot(df['Item_Outlet_Sales'])
# Out:
# C:\Users\mehta\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Density'>

# %%
#Log transformation
df['Item_Outlet_Sales']= np.log(1+df['Item_Outlet_Sales'])
sns.distplot(df['Item_Outlet_Sales'])
# Out:
# C:\Users\mehta\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Density'>

# %%
#For categorical variables

sns.countplot(df['Item_Fat_Content'])
# Out:
# C:\Users\mehta\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='count'>

# %%
plt.figure(figsize=(24,10))
sns.countplot(df['Item_Type'])
# Out:
# C:\Users\mehta\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Item_Type', ylabel='count'>

# %%
sns.countplot(df['Outlet_Establishment_Year'])
# Out:
# C:\Users\mehta\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Outlet_Establishment_Year', ylabel='count'>

# %%
#Correlation Matrix

corr=df.corr()
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
label= LabelEncoder()
df['Outlet']= label.fit_transform(df['Outlet_Identifier'])
categ=['Item_Fat_Content','Item_Type','Outlet_Size','Outlet_Location_Type','Outlet_Type','New_Item_type']

for col in categ:
    df[col]= label.fit_transform(df[col])

# %% [markdown]
# ### One Hot Encoding

# %%
df= pd.get_dummies(df, columns=['Item_Fat_Content','Item_Type','Outlet_Size','Outlet_Location_Type','Outlet_Type','New_Item_type'])
df
# Out:
#       Item_Identifier  Item_Weight  Item_Visibility  Item_MRP  \
# 0               FDA15         9.30         0.016047  249.8092
# 1               DRC01         5.92         0.019278   48.2692
# 2               FDN15        17.50         0.016760  141.6180
# 3               FDX07        19.20         0.065953  182.0950
# 4               NCD19         8.93         0.065953   53.8614
# ...               ...          ...              ...       ...
# 14199           FDB58        10.50         0.013496  141.3154
# 14200           FDD47         7.60         0.142991  169.1448
# 14201           NCO17        10.00         0.073529  118.7440
# 14202           FDJ26        15.30         0.065953  214.6218
# 14203           FDU37         9.50         0.104720   79.7960
#
#       Outlet_Identifier  Outlet_Establishment_Year  Item_Outlet_Sales    src  \
# 0                OUT049                       1999           8.225808  train
# ...

# %% [markdown]
# ### Model Building

# %%
train= df.loc[df['src']=='train']
test= df.loc[df['src']=='test']

# %%
train.drop(['src'], axis=1, inplace=True)
test.drop(['src'], axis=1, inplace=True)
# Out:
# C:\Users\mehta\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
X_train= train.drop(['Item_Identifier','Outlet_Identifier','Outlet_Establishment_Year','Item_Outlet_Sales'], axis=1)
Y_train= train['Item_Outlet_Sales']
x_test= test.drop(['Item_Identifier','Outlet_Identifier','Outlet_Establishment_Year','Item_Outlet_Sales'], axis=1)

# %%
##Applying Linear Regression
from sklearn.linear_model import LinearRegression 
model = LinearRegression()
model.fit(X_train,Y_train)

y_pred= model.predict(x_test)
y_pred
# Out:
# array([7.26634425, 7.03692691, 6.39016797, ..., 7.29352745, 8.19073747,
#        6.99749493])

# %%
accuracy= model.score(X_train,Y_train)*100
accuracy
# Out:
# 72.12978062904168

# %% [markdown]
# # Model Training
